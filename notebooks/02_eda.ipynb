# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
df=pd.read_csv("D:\GOPU\DATA SCIENCE\GITHUB_PRO\customer-churn-prediction\data/telco_churn.csv")

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %% [markdown]
# This shows the proportion of customers who churned vs stayed.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.tight_layout()
plt.show()

# %% [markdown]
# Details said that month-to-month contracts churn more than long-term customers

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn',y='MonthlyCharges',data=df)
plt.title("Monthly Charges vs Churn")
plt.tight_layout()
plt.show()

# %% [markdown]
# Higher monthly charges increase churn probability.

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=df,x='tenure',hue='Churn',bins=30,kde=True)
plt.title("Tenure vs Churn")
plt.tight_layout()
plt.show()

# %% [markdown]
# New customers are more likely to churn

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.savefig("D:\GOPU\DATA SCIENCE\GITHUB_PRO\customer-churn-prediction\images/churn_by_contract.png")
plt.show()
